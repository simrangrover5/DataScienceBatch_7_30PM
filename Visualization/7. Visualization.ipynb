# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import warnings

# %%
warnings.filterwarnings(action="ignore")

# %%
tip = sns.load_dataset("tips")
mpg = sns.load_dataset("mpg")

# %%
mat = pd.read_csv("../exercise/matches.csv")

# %%
mat.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
plt.rcParams['figure.figsize'] = 11, 5
plt.rcParams['figure.dpi'] = 100

# %%
val = mat['city'].value_counts()[:7].values
labels = mat['city'].value_counts()[:7].index

# %%
plt.pie(val, labels=labels)
plt.show()

# %%
plt.pie(val, labels=labels, autopct="%.5f")
plt.show()

# %%
labels
# Out:
# Index(['Mumbai', 'Kolkata', 'Delhi', 'Bangalore', 'Hyderabad', 'Chennai',
#        'Jaipur'],
#       dtype='object')

# %%
plt.pie(val, labels=labels, autopct="%.5f", explode=[0.5]+[0]*6)
plt.show()

# %%
plt.pie(val, labels=labels, autopct="%.5f", explode=[0.2]+[0]*6)
plt.show()

# %%
plt.pie(val, labels=labels, autopct="%.5f", explode=[3]+[0]*6)
plt.show()

# %%
plt.pie(val, labels=labels, autopct="%.2f", explode=[0.5, 0.1, 0.2, 0.15, 0.25, 0.3, 1])
plt.show()

# %%
plt.pie(val, labels=labels, autopct="%.2f", explode=[0.2]+[0]*6, shadow=True, labeldistance=1.2)
plt.show()

# %%
plt.pie(val, labels=labels, autopct="%.2f", explode=[0.2]+[0]*6, shadow=True, labeldistance=0.9, pctdistance=1.2)
plt.show()

# %%
plt.pie(val, labels=labels, autopct="%.2f", explode=[0.2]+[0]*6, shadow=True, labeldistance=0.7, pctdistance=1.2)
plt.show()

# %%
from generate_color import colors

# %%
plt.pie(val, labels=labels, autopct="%.2f", explode=[0.2]+[0]*6, shadow=True, labeldistance=0.9, 
        pctdistance=1.2, textprops={"color":"#123456", "fontsize":12}, colors=[colors() for i in range(len(val))])
plt.show()

# %%
help(plt.pie)
# Out:
# Help on function pie in module matplotlib.pyplot:
#
# pie(x, explode=None, labels=None, colors=None, autopct=None, pctdistance=0.6, shadow=False, labeldistance=1.1, startangle=0, radius=1, counterclock=True, wedgeprops=None, textprops=None, center=(0, 0), frame=False, rotatelabels=False, *, normalize=None, data=None)
#     Plot a pie chart.
#
#     Make a pie chart of array *x*.  The fractional area of each wedge is
#     given by ``x/sum(x)``.  If ``sum(x) < 1``, then the values of *x* give
#     the fractional area directly and the array will not be normalized. The
#     resulting pie will have an empty wedge of size ``1 - sum(x)``.
#
#     The wedges are plotted counterclockwise, by default starting from the
#     x-axis.
#
#     Parameters
#     ----------
#     x : 1D array-like
#         The wedge sizes.
#
#     explode : array-like, default: None
#         If not *None*, is a ``len(x)`` array which specifies the fraction
# ...

# %%
plt.pie(val, labels=labels, autopct="%.2f", explode=[0.2]+[0]*6, startangle=90,
        textprops={"color":"#123456", "fontsize":12}, colors=[colors() for i in range(len(val))])
plt.show()

# %%
plt.pie(val, labels=labels, autopct="%.2f", explode=[0.2]+[0]*6, startangle=90,
        textprops={"color":"#123456", "fontsize":12}, colors=[colors() for i in range(len(val))], rotatelabels=True)
plt.show()

# %%
plt.boxplot([tip['total_bill'], tip['tip']])
plt.show()

# %%
max(tip['total_bill'])
# Out:
# 50.81

# %%
plt.boxplot([tip['tip']])
plt.show()

# %%
tip['tip'].median()
# Out:
# 2.9

# %%
tip['tip'].quantile([0.25, 0.50, 0.75])
# Out:
# 0.25    2.0000
# 0.50    2.9000
# 0.75    3.5625
# Name: tip, dtype: float64

# %%
plt.boxplot(tip['total_bill'], showmeans=True, showbox=False, showcaps=False, showfliers=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b812ad0280>,
# ...
#  'caps': [],
#  'boxes': [],
#  'medians': [<matplotlib.lines.Line2D at 0x1b81207a3d0>],
#  'fliers': [],
#  'means': [<matplotlib.lines.Line2D at 0x1b81319d2e0>]}

# %%
data
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b812bf58e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b811e05880>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b812bf54c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b8131d6400>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b8131d6e80>],
#  'means': [<matplotlib.lines.Line2D at 0x1b8131d6a30>]}

# %%
data = plt.boxplot(tip['total_bill'], showmeans=True)
for w in data['whiskers']:
    w.set_color("green")
    w.set_lw(2)

# %%
data = plt.boxplot(tip['total_bill'], showmeans=True, whiskerprops={"color":"green", "lw":2}, 
                  flierprops={"marker":"*", "mfc":"red", "mec":"grey"}, capprops={"color":"#123456"}, 
                  boxprops={"ls":"--"}, medianprops={"lw":2})

# %%
data
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b814a744c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b814a97250>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b814a74370>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b814a97af0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b8151437c0>],
#  'means': [<matplotlib.lines.Line2D at 0x1b814a97df0>]}

# %%
sns.light_palette("grey")
# Out:
# [(0.9434690573207286, 0.9435003513085646, 0.9433775439604699),
#  (0.855167402719328, 0.8551924379095968, 0.855094192031121),
#  (0.7668657481179273, 0.7668845245106289, 0.7668108401017721),
#  (0.6785640935165267, 0.6785766111116611, 0.6785274881724233),
#  (0.5902624389151261, 0.5902686977126933, 0.5902441362430744),
#  (0.5019607843137255, 0.5019607843137255, 0.5019607843137255)]

# %%
sns.lineplot(tip['total_bill'][:], tip['tip'][:])
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(x="total_bill", y="tip", data=tip)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(x="total_bill", y="tip", data=tip, marker='*', mfc='black', color="red", label="FLOW")
plt.legend()
plt.grid()

# %%
sns.scatterplot(tip['total_bill'], tip['tip'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
mat[:5]
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
sns.scatterplot(tip['total_bill'], tip['tip'], hue=tip['sex'], size=tip['smoker'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='displacement', y='horsepower', data=mpg, hue='origin', palette="Accent")
# Out:
# <AxesSubplot:xlabel='displacement', ylabel='horsepower'>

# %%
sns.scatterplot(x='displacement', y='horsepower', data=mpg, hue='origin', palette="Blues")
# Out:
# <AxesSubplot:xlabel='displacement', ylabel='horsepower'>

# %%
mpg[:5]
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.scatterplot(x='displacement', y='horsepower', data=mpg, hue='origin', palette="Blues", size="model_year")
# Out:
# <AxesSubplot:xlabel='displacement', ylabel='horsepower'>

# %%
data

# %%
sns.scatterplot(x='displacement', y='horsepower', data=mpg, size='origin', palette="Accent", hue="model_year")
plt.tick_params(labelcolor="coral")

# %%
mpg['model_year'].value_counts()
# Out:
# 73    40
# 78    36
# 76    34
# 82    31
# 75    30
# 81    29
# 80    29
# 79    29
# 70    29
# 77    28
# 72    28
# 71    28
# 74    27
# Name: model_year, dtype: int64

# %%
mpg.origin.value_counts()
# Out:
# usa       249
# japan      79
# europe     70
# Name: origin, dtype: int64

# %%
color = mpg['origin'].map({"usa":"green", "japan":"yellow", "europe": "red"})

# %%
mpg['displacement'].__len__()
# Out:
# 398

# %%
len(color)
# Out:
# 398

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
sns.scatterplot(x=mpg['displacement'], y=mpg['acceleration'], c=color)
plt.tick_params(labelcolor="coral")

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
val
# Out:
# array([101,  77,  74,  66,  64,  57,  47], dtype=int64)

# %%
labels
# Out:
# Index(['Mumbai', 'Kolkata', 'Delhi', 'Bangalore', 'Hyderabad', 'Chennai',
#        'Jaipur'],
#       dtype='object')

# %%
sns.barplot(labels, val)
# Out:
# <AxesSubplot:>

# %%
sns.barplot(val, labels)
# Out:
# <AxesSubplot:>

# %%
dates = pd.date_range("011621", periods=10)
jaipur = np.random.randint(10, 50, 10)
delhi = np.random.randint(10, 50, 10)

# %%
delhi
# Out:
# array([23, 15, 16, 38, 31, 28, 28, 20, 21, 48])

# %%
jaipur
# Out:
# array([29, 35, 40, 44, 11, 39, 32, 38, 49, 35])

# %%
sns.barplot(dates, jaipur, dodge=True, alpha=0.5, )
sns.barplot(dates, delhi)
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(tip['total_bill'], tip['tip'], hue=tip['sex'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
i = tip['sex'].value_counts().index
v = tip['sex'].value_counts().values

# %%
sns.barplot(i, v, alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
sns.countplot(tip['sex'], hue=tip['smoker'])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
### matplotlib live plot

# %%
from matplotlib.animation import FuncAnimation

# %%
import numpy as np
import matplotlib.pyplot as plt
fig,ax = plt.subplots()
explode=[0.01,0.01,0.01,0.01] #pop out each slice from the pie
def getmepie(i):
    def absolute_value(val): #turn % back to a number
        a  = np.round(val/100.*df1.head(i).max().sum(), 0)
        return int(a)
    ax.clear()
    plot = df1.head(i).max().plot.pie(y=df1.columns,autopct=absolute_value, label='',explode = explode, shadow = True)
    plot.set_title('Total Number of Deaths\n' + str(df1.index[min( i, len(df1.index)-1 )].strftime('%y-%m-%d')), fontsize=12)
import matplotlib.animation as ani
animator = ani.FuncAnimation(fig, getmepie, interval = 200)
plt.show()

# %%
mat[['win_by_runs', 'win_by_wickets']].head(1).max().sum()
# Out:
# 35

# %%
# %matplotlib notebook

# %%
fig, ax = plt.subplots()
df1 = mat[['win_by_runs', 'win_by_wickets']]
def makepie(i):
    ax.clear()
    df1.head(i).max().plot.pie(y=df1.columns, autopct='%.2f', shadow=True)

ani = FuncAnimation(fig, makepie)
plt.show()
# Out:
# <img src="data:," width="0">
