# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rcParamsDefault
# Out:
# RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.avconv_args': [],
#           'animation.avconv_path': 'avconv',
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': [],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.html_args': [],
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': 'line',
#           'axes.edgecolor': 'black',
#           'axes.facecolor': 'white',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
# ...

# %%
x = [1, 2, 3, 4, 5]
y = [5, 6, 3, 7, 9]
y1 = [3, 4, 7, 8, 9]

# %%
plt.fill_between(x, y, y1)

# %%
plt.plot(y, x, 'r')
plt.plot(y1, x, 'y')
plt.fill_betweenx(x, y, y1)

# %%
plt.rcParams['figure.figsize'] = 10, 6
plt.rcParams['figure.dpi'] = 100

# %%
x = np.linspace(-5, 5, 100)
data = sns.load_dataset("tips")

# %%
title = {"fontsize":25, "color":"#12abcd", "fontfamily":"monospace"}
label = {"fontsize":15, "color":"#abcd12", "fontfamily":"monospace"}

# %%
fig = plt.figure()
ax1 = fig.add_axes([0, 0, 0.5, 0.5])
ax2 = fig.add_axes([0.6, 0.6, 0.5, 0.5])
ax1.plot(x, x**2, 'ro', label="$X^2$")
ax2.plot(x, x**3, 'bo', label="$X^3$")
ax1.legend()
ax2.legend()
ax1.set_title("X VS $X^2$", fontdict=title)
ax2.set_title("X VS $X^3$", fontdict=title)
ax1.set_xlabel("X", fontdict=label)
ax1.set_ylabel("$X^2$", fontdict=label)
ax2.set_xlabel("X", fontdict=label)
ax2.set_ylabel("$X^3$", fontdict=label)
ax1.grid()
ax2.grid()
#plt.legend()
plt.show()

# %%
print(dir(ax1))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_add_text', '_adjustable', '_agg_filter', '_alias_map', '_alpha', '_anchor', '_animated', '_aspect', '_autoscaleXon', '_autoscaleYon', '_autotitlepos', '_axes', '_axes_locator', '_axisbelow', '_box_aspect', '_clipon', '_clippath', '_contains', '_convert_dx', '_current_image', '_default_contains', '_facecolor', '_fill_between_x_or_y', '_frameon', '_gci', '_gen_axes_patch', '_gen_axes_spines', '_get_axis_list', '_get_axis_map', '_get_clipping_extent_bbox', '_get_lines', '_get_patches_for_fill', '_get_view', '_gid', '_gridOn', '_in_layout', '_init_axis', '_label', '_layoutbox', '_left_title', '_make_twin_axes', '_mo
# ...

# %%
ax1.get_xticks()
# Out:
# array([-6., -4., -2.,  0.,  2.,  4.,  6.])

# %%
ax2.get_xticks()
# Out:
# array([-6., -4., -2.,  0.,  2.,  4.,  6.])

# %%
ax1.get_xticklabels()
# Out:
# [Text(-6.0, 0, '−6'),
#  Text(-4.0, 0, '−4'),
#  Text(-2.0, 0, '−2'),
#  Text(0.0, 0, '0'),
#  Text(2.0, 0, '2'),
#  Text(4.0, 0, '4'),
#  Text(6.0, 0, '6')]

# %%
list(ax1.get_xticklines()).__len__()
# Out:
# 14

# %%
line = ax1.get_xticklines()[0]

# %%
line.get_xdata()
# Out:
# (-6.0,)

# %%
for l in ax1.get_xticklines():
    print(l.get_xdata())
# Out:
# (-6.0,)
# (-6.0,)
# (-4.0,)
# (-4.0,)
# (-2.0,)
# (-2.0,)
# (0.0,)
# (0.0,)
# (2.0,)
# (2.0,)
# (4.0,)
# (4.0,)
# (6.0,)
# (6.0,)

# %%
line.axes

# %%
line.get_lw()
# Out:
# 1.5

# %%
fig = plt.figure()
ax1 = fig.add_axes([0, 0, 0.5, 0.5])
ax2 = fig.add_axes([0.6, 0.6, 0.5, 0.5])
ax1.plot(x, x**2, 'ro', label="$X^2$")
ax2.plot(x, x**3, 'bo', label="$X^3$")
ax1.legend()
ax2.legend()
ax1.set_title("X VS $X^2$", fontdict=title)
ax2.set_title("X VS $X^3$", fontdict=title)
ax1.set_xlabel("X", fontdict=label)
ax1.set_ylabel("$X^2$", fontdict=label)
ax2.set_xlabel("X", fontdict=label)
ax2.set_ylabel("$X^3$", fontdict=label)
ax1.grid()
ax2.grid()
line = ax1.get_xticklines()[3]
line.set_ls("--")
#plt.legend()
plt.show()

# %%
line.get_xydata()
# Out:
# array([[-4.,  1.]])

# %%
for l in ax1.get_xticklines():
    print(l.get_xdata())
    print(l.get_xydata())
    print(l.get_ls())
# Out:
# (-6.0,)
# [[-6.  0.]]
# None
# (-6.0,)
# [[-6.  1.]]
# None
# (-4.0,)
# [[-4.  0.]]
# None
# (-4.0,)
# [[-4.  1.]]
# --
# (-2.0,)
# [[-2.  0.]]
# None
# (-2.0,)
# [[-2.  1.]]
# None
# (0.0,)
# [[0. 0.]]
# None
# (0.0,)
# [[0. 1.]]
# None
# (2.0,)
# [[2. 0.]]
# None
# (2.0,)
# [[2. 1.]]
# None
# (4.0,)
# [[4. 0.]]
# None
# (4.0,)
# [[4. 1.]]
# None
# (6.0,)
# [[6. 0.]]
# None
# (6.0,)
# [[6. 1.]]
# None

# %%
ax1.get_yticks()
# Out:
# array([-5.,  0.,  5., 10., 15., 20., 25., 30.])

# %%
ax1.get_ylim()
# Out:
# (-1.2473217018671567, 26.249872461993675)

# %%
fig = plt.figure()
ax1 = fig.add_axes([0, 0, 0.5, 0.5])
ax2 = fig.add_axes([0.6, 0.6, 0.5, 0.5])
ax1.plot(x, x**2, 'ro', label="$X^2$")
ax2.plot(x, x**3, 'bo', label="$X^3$")
ax1.legend()
ax2.legend()
ax1.set_title("X VS $X^2$", fontdict=title)
ax2.set_title("X VS $X^3$", fontdict=title)
ax1.set_xlabel("X", fontdict=label)
ax1.set_ylabel("$X^2$", fontdict=label)
ax2.set_xlabel("X", fontdict=label)
ax2.set_ylabel("$X^3$", fontdict=label)
ax1.grid()
ax2.grid()
line = ax1.get_xticklines()[3]
line.set_ls("--")
ax1.set_ylim([0, 25.5])
#plt.legend()
plt.show()

# %%
print(dir(ax1.spines['left']))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_adjust_location', '_agg_filter', '_alias_map', '_alpha', '_animated', '_antialiased', '_axes', '_bind_draw_path_function', '_bounds', '_capstyle', '_clipon', '_clippath', '_contains', '_convert_xy_units', '_dashes', '_dashoffset', '_default_contains', '_edge_default', '_edgecolor', '_ensure_position_is_set', '_facecolor', '_fill', '_get_clipping_extent_bbox', '_gid', '_hatch', '_hatch_color', '_in_layout', '_joinstyle', '_label', '_linestyle', '_linewidth', '_mouseover', '_oid', '_original_edgecolor', '_original_facecolor', '_patch_transform', '_patch_type', '_path', '_path_effects', '_picker', '_position', '_process_radius', '
# ...

# %%
fig = plt.figure()
ax1 = fig.add_axes([0, 0, 0.5, 0.5])
ax2 = fig.add_axes([0.6, 0.6, 0.5, 0.5])
ax1.plot(x, x**2, 'ro', label="$X^2$")
ax2.plot(x, x**3, 'bo', label="$X^3$")
ax1.legend()
ax2.legend()
ax1.set_title("X VS $X^2$", fontdict=title)
ax2.set_title("X VS $X^3$", fontdict=title)
ax1.set_xlabel("X", fontdict=label)
ax1.set_ylabel("$X^2$", fontdict=label)
ax2.set_xlabel("X", fontdict=label)
ax2.set_ylabel("$X^3$", fontdict=label)
#ax1.grid()
ax2.grid()
line = ax1.get_xticklines()[3]
line.set_ls("--")
ax1.set_ylim([0, 25.5])
ax1.spines['left'].set_color("blue")
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_color("blue")
#plt.legend()
plt.show()

# %%
mat = pd.read_csv("C:/batches/online_batch/batch9am/matches.csv")

# %%
mat.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
mat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
mat['season'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
# %%writefile generate_color.py

def colors():
    return "#"+"".join(np.random.choice(list('abcdef123456789'), 6))
# Out:
# Writing generate_color.py

# %%
"#"+"".join(np.random.choice(list('abcdef123456789'), 6))
# Out:
# '#8d7d42'

# %%
def colors():
    return "#"+"".join(np.random.choice(list('abcdef123456789'), 6))

# %%
fig = plt.figure(facecolor="black")
ax1 = fig.add_axes([0, 0, 0.5, 0.5], facecolor="black")
ax2 = fig.add_axes([0.6, 0, 0.5, 0.5], facecolor="black")
ax2.hist(mat['win_by_wickets'], bins=20, ec='w')
mat['season'].value_counts().plot(kind="bar", ax=ax1, color=[colors() for i in range(12)])
titles = ['Season Barchart', 'Histogram Win_by_Wickets']
axes = [ax1, ax2]
for i in range(len(axes)):
    axes[i].set_title(titles[i], fontdict=title)
    axes[i].tick_params(labelcolor="white", labelsize=10, color="white")
    for side in ['left', 'right', 'top', 'bottom']:
        color = 'red' if side in ['left', 'right'] else 'blue'
        axes[i].spines[side].set_color(color)
        axes[i].spines[side].set_lw(2)
        axes[i].spines[side].set_ls("--")
ax1.set_xlabel("SEASON", fontdict=label)
ax1.set_ylabel("VALUES", fontdict=label)
ax2.set_xlabel("WIN_BY_WICKETS", fontdict=label)
ax2.set_ylabel("COUNT", fontdict=label)
plt.show()

# %%
mat['player_of_match'].value_counts()[:10]
# Out:
# CH Gayle          21
# AB de Villiers    20
# MS Dhoni          17
# RG Sharma         17
# DA Warner         17
# YK Pathan         16
# SR Watson         15
# SK Raina          14
# G Gambhir         13
# AM Rahane         12
# Name: player_of_match, dtype: int64

# %%
(mat['toss_decision'] == "field")
# Out:
# 0      field
# 1      field
# 2      field
# 3      field
# 4        bat
#        ...
# 751    field
# 752      bat
# 753    field
# 754    field
# 755      bat
# Name: toss_decision, Length: 756, dtype: object

# %%
fig = plt.figure(facecolor="black")
ax1 = fig.add_axes([0, 0, 0.5, 0.5], facecolor="black")
ax2 = fig.add_axes([0.6, 0, 0.5, 0.5], facecolor="black")
#ax = fig.add_axes([0, 0.6, 1.2, 0.05], facecolor="white")
ax3 = fig.add_axes([0.6, 0.7, 0.5, 0.5], facecolor="#abcdef")
ax4 = fig.add_axes([0, 0.7, 0.5, 0.5])
ax2.hist(mat['win_by_wickets'], bins=20, ec='w')
mat['player_of_match'].value_counts()[:10].plot(kind="bar", ax=ax3, color=[colors() for i in range(12)])
mat['season'].value_counts().plot(kind="bar", ax=ax1, color=[colors() for i in range(12)])
titles = ['Season Barchart', 'Histogram Win_by_Wickets', "Player_of_match Barchart"]
axes = [ax1, ax2, ax3]
for i in range(len(axes)):
    axes[i].set_title(titles[i], fontdict=title)
    axes[i].tick_params(labelcolor="white", labelsize=10, color="white")
    for side in ['left', 'right', 'top', 'bottom']:
        color = 'red' if side in ['left', 'right'] else 'blue'
        axes[i].spines[side].set_color(color)
        axes[i].spines[side].set_lw(2)
        axes[i].spines[side].set_ls("--")
ax3.set_xticklabels(ax3.get_xticklabels(), rotation=30)
ax1.set_xlabel("SEASON", fontdict=label)
ax1.set_ylabel("VALUES", fontdict=label)
ax2.set_xlabel("WIN_BY_WICKETS", fontdict=label)
ax2.set_ylabel("COUNT", fontdict=label)
plt.show()

# %% [markdown]
# ### The number of times team wins the game when the match is held in that particular city as team consists of
