# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
apple = pd.read_csv('temp_apple.csv', index_col=0)

# %%
apple.head()
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41

# %%
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8465 entries, 1980-12-12 to 2014-07-08
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       8465 non-null   float64
#  1   High       8465 non-null   float64
#  2   Low        8465 non-null   float64
#  3   Close      8465 non-null   float64
#  4   Volume     8465 non-null   int64
#  5   Adj Close  8465 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 462.9+ KB

# %%
apple.index = pd.to_datetime(apple.index)

# %%
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8465 entries, 1980-12-12 to 2014-07-08
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       8465 non-null   float64
#  1   High       8465 non-null   float64
#  2   Low        8465 non-null   float64
#  3   Close      8465 non-null   float64
#  4   Volume     8465 non-null   int64
#  5   Adj Close  8465 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 462.9 KB

# %%
apple.last("M")
# Out:
#              Open   High    Low  Close    Volume  Adj Close
# Date
# 2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52
# 2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48
# 2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03
# 2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35

# %%
apple.last("2M")
# Out:
#               Open    High     Low   Close     Volume  Adj Close
# Date
# 2014-06-02  633.96  634.83  622.50  628.65   92337700      89.81
# 2014-06-03  628.46  638.74  628.25  637.54   73177300      91.08
# 2014-06-04  637.44  647.89  636.11  644.82   83870500      92.12
# 2014-06-05  646.20  649.37  642.61  647.35   75951400      92.48
# 2014-06-06  649.90  651.26  644.47  645.57   87484600      92.22
# 2014-06-09   92.70   93.88   91.75   93.70   75415000      93.70
# 2014-06-10   94.73   95.05   93.57   94.25   62777000      94.25
# 2014-06-11   94.13   94.76   93.47   93.86   45681000      93.86
# 2014-06-12   94.04   94.12   91.90   92.29   54749000      92.29
# 2014-06-13   92.20   92.44   90.88   91.28   54525000      91.28
# 2014-06-16   91.51   92.75   91.45   92.20   35561000      92.20
# 2014-06-17   92.31   92.70   91.80   92.08   29689800      92.08
# 2014-06-18   92.27   92.29   91.35   92.18   33493800      92.18
# ...

# %%
apple.last("Y").sum()
# Out:
# Open         6.160437e+04
# High         6.209592e+04
# Low          6.117566e+04
# Close        6.166672e+04
# Volume       9.372162e+09
# Adj Close    1.042806e+04
# dtype: float64

# %%
apple.last("M").sum()
# Out:
# Open         4.714700e+02
# High         4.750200e+02
# Low          4.674400e+02
# Close        4.723500e+02
# Volume       2.109183e+08
# Adj Close    4.723500e+02
# dtype: float64

# %%
apple.last("H")
# Out:
#              Open  High    Low  Close    Volume  Adj Close
# Date
# 2014-07-08  96.27  96.8  93.92  95.35  65130000      95.35

# %%
apple.last("D")
# Out:
#              Open  High    Low  Close    Volume  Adj Close
# Date
# 2014-07-08  96.27  96.8  93.92  95.35  65130000      95.35

# %%
apple.last("20D")
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 2014-06-19  92.29  92.30  91.34  91.86   35486400      91.86
# 2014-06-20  91.85  92.55  90.90  90.91  100813200      90.91
# 2014-06-23  91.32  91.62  90.60  90.83   43618200      90.83
# 2014-06-24  90.75  91.74  90.19  90.28   38988300      90.28
# 2014-06-25  90.21  90.70  89.65  90.36   36852200      90.36
# 2014-06-26  90.37  91.05  89.80  90.90   32595800      90.90
# 2014-06-27  90.82  92.00  90.77  91.98   64006800      91.98
# 2014-06-30  92.10  93.73  92.09  92.93   49482300      92.93
# 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35

# %%
apple.last("20H")
# Out:
#              Open  High    Low  Close    Volume  Adj Close
# Date
# 2014-07-08  96.27  96.8  93.92  95.35  65130000      95.35

# %%
apple.index[0]
# Out:
# Timestamp('1980-12-12 00:00:00')

# %%
plt.rcParams['figure.dpi'] = 100

# %%
apple.last("Y")['Open'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
apple.last("2Y")['Open'].plot(color='red')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
apple.resample("D").count()[:5]
# Out:
#             Open  High  Low  Close  Volume  Adj Close
# Date
# 1980-12-12     1     1    1      1       1          1
# 1980-12-13     0     0    0      0       0          0
# 1980-12-14     0     0    0      0       0          0
# 1980-12-15     1     1    1      1       1          1
# 1980-12-16     1     1    1      1       1          1

# %%
apple[:5]
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41

# %%
apple.resample("D").sum()[:5]
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
# 1980-12-13   0.00   0.00   0.00   0.00          0       0.00
# 1980-12-14   0.00   0.00   0.00   0.00          0       0.00
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39

# %%
apple.resample("M").count()[:5]
# Out:
#             Open  High  Low  Close  Volume  Adj Close
# Date
# 1980-12-31    13    13   13     13      13         13
# 1981-01-31    21    21   21     21      21         21
# 1981-02-28    19    19   19     19      19         19
# 1981-03-31    22    22   22     22      22         22
# 1981-04-30    21    21   21     21      21         21

# %%
apple.resample("BM").count()[:5]
# Out:
#             Open  High  Low  Close  Volume  Adj Close
# Date
# 1980-12-31    13    13   13     13      13         13
# 1981-01-30    21    21   21     21      21         21
# 1981-02-27    19    19   19     19      19         19
# 1981-03-31    22    22   22     22      22         22
# 1981-04-30    21    21   21     21      21         21

# %%
apple.resample("BM").count().tail()
# Out:
#             Open  High  Low  Close  Volume  Adj Close
# Date
# 2014-03-31    21    21   21     21      21         21
# 2014-04-30    21    21   21     21      21         21
# 2014-05-30    21    21   21     21      21         21
# 2014-06-30    21    21   21     21      21         21
# 2014-07-31     5     5    5      5       5          5

# %%
apple.resample("Y").count()
# Out:
#             Open  High  Low  Close  Volume  Adj Close
# Date
# 1980-12-31    13    13   13     13      13         13
# 1981-12-31   252   252  252    252     252        252
# 1982-12-31   253   253  253    253     253        253
# 1983-12-31   252   252  252    252     252        252
# 1984-12-31   253   253  253    253     253        253
# 1985-12-31   253   253  253    253     253        253
# 1986-12-31   253   253  253    253     253        253
# 1987-12-31   253   253  253    253     253        253
# 1988-12-31   253   253  253    253     253        253
# 1989-12-31   252   252  252    252     252        252
# 1990-12-31   253   253  253    253     253        253
# 1991-12-31   253   253  253    253     253        253
# 1992-12-31   254   254  254    254     254        254
# 1993-12-31   253   253  253    253     253        253
# 1994-12-31   252   252  252    252     252        252
# 1995-12-31   252   252  252    252     252        252
# ...

# %%
apple.resample("Y").sum()['Open'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
apple.resample("Y").sum()['Volume'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
apple.resample("2M").count()
# Out:
#             Open  High  Low  Close  Volume  Adj Close
# Date
# 1980-12-31    13    13   13     13      13         13
# 1981-02-28    40    40   40     40      40         40
# 1981-04-30    43    43   43     43      43         43
# 1981-06-30    42    42   42     42      42         42
# 1981-08-31    42    42   42     42      42         42
# ...          ...   ...  ...    ...     ...        ...
# 2013-12-31    41    41   41     41      41         41
# 2014-02-28    40    40   40     40      40         40
# 2014-04-30    42    42   42     42      42         42
# 2014-06-30    42    42   42     42      42         42
# 2014-08-31     5     5    5      5       5          5
#
# [203 rows x 6 columns]

# %%
apple.resample("2Y").count()
# Out:
#             Open  High  Low  Close  Volume  Adj Close
# Date
# 1980-12-31    13    13   13     13      13         13
# 1982-12-31   505   505  505    505     505        505
# 1984-12-31   505   505  505    505     505        505
# 1986-12-31   506   506  506    506     506        506
# 1988-12-31   506   506  506    506     506        506
# 1990-12-31   505   505  505    505     505        505
# 1992-12-31   507   507  507    507     507        507
# 1994-12-31   505   505  505    505     505        505
# 1996-12-31   506   506  506    506     506        506
# 1998-12-31   505   505  505    505     505        505
# 2000-12-31   504   504  504    504     504        504
# 2002-12-31   500   500  500    500     500        500
# 2004-12-31   504   504  504    504     504        504
# 2006-12-31   503   503  503    503     503        503
# 2008-12-31   504   504  504    504     504        504
# 2010-12-31   504   504  504    504     504        504
# ...

# %%
apple.resample("BQS").count()
# Out:
#             Open  High  Low  Close  Volume  Adj Close
# Date
# 1980-10-01    13    13   13     13      13         13
# 1981-01-01    62    62   62     62      62         62
# 1981-04-01    63    63   63     63      63         63
# 1981-07-01    63    63   63     63      63         63
# 1981-10-01    64    64   64     64      64         64
# ...          ...   ...  ...    ...     ...        ...
# 2013-07-01    64    64   64     64      64         64
# 2013-10-01    64    64   64     64      64         64
# 2014-01-01    61    61   61     61      61         61
# 2014-04-01    63    63   63     63      63         63
# 2014-07-01     5     5    5      5       5          5
#
# [136 rows x 6 columns]

# %%
apple.resample("BQ").count()
# Out:
# Open         8465
# High         8465
# Low          8465
# Close        8465
# Volume       8465
# Adj Close    8465
# dtype: int64

# %%
s = apple.resample("BQ").sum()

# %%
s[s['Open'] == s['Open'].max()]
# Out:
#                Open      High       Low     Close      Volume  Adj Close
# Date
# 2012-09-28  40307.2  40629.56  39988.28  40354.24  6596215500    5524.27

# %% [markdown]
# ### Choose any dataset, analysis it and make report
